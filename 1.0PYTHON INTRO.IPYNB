# %% [markdown]
# **1**

# %% [markdown]
# **1️⃣ Easy to learn & use  Python ka syntax simple aur readable hota hai.
#
# 2️⃣ High-level language Programmer ko memory management ki tension nahi hoti.
#
# 3️⃣ Interpreted language  Code line-by-line execute hota hai, debugging easy hoti hai.
#
# 4️⃣ Large and supportive community Problems ke solutions aur help easily mil jaati hai.
#
# 5️⃣ Cross-platform  Same Python code Windows, Linux aur macOS par chalta hai.
#
# 6️⃣ Integration capability  Python easily databases, APIs aur dusre languages ke saath kaam karta hai.
#
# 7️⃣ Rapid prototyping & development  Kam code me jaldi prototype aur software develop ho jata hai.
#
# 8️⃣ Rich standard library  Python me pehle se bahut saari useful libraries hoti hain.
#
# 9️⃣ Open source & free Python free hai aur koi license fee nahi lagti.
#
# 🔟 Versatile language Python web, AI, ML, data science, automation sab me use hoti hai.**|

# %% [markdown]
# **2**

# %% [markdown]
# **Python ek programming language hai
# Jiska use karke hum computer ko kaam karna sikhate hain.
#
# Python se kya-kya kar sakte hai?
#
# Software / Apps bana sakte ho
#  Websites (Django, Flask) bana sakte ho
# DAta Science / AI / ML me use hota hai
#  Automation (repeat kaam automatically)
#  Games aur scripts bhi
#
# Python easy kyu hai?
#
#  Simple English jaisa code hota hai
#  Beginners ke liye best hai
#  Jobs aur demand bahut hai
#
# Example (Python code)
# print("Hello Bhai")
#
#
# Output: Hello Bhai
#
# Aap chaho to mai Python ka basic roadmap bhi bana ke dunga (0 to beginner).**

# %% [markdown]
# **3**

# %% [markdown]
# ** 1) Python easy hai
#
# Python ka code simple English jaisa hota hai.
#
# Python
#
# print("Hello")
#
#
# C
#
# printf("Hello");
#
#
#   C me jyada rules + symbols hote hai.
#  2) Python me code kam likhna padta hai
#
# Python me short code me kaam ho jata hai.
# Dusri languages me long code hota hai.
#
#  3) Python slow (thoda) hota hai
#
# Python C/C++ se slow hota hai kyunki C/C++ fast run karta hai.
# But Python learning + work ke liye best hai.
#
#  4) Python me semicolon ; nahi chahiye
#
# Java/C/JS me mostly ; use hota hai
# Python me nahi
#
# 5) Python indentation important hai
#
# Python me spacing (gap) se code chalta hai.
#
# Example:
#
# if 5 > 2:
#     print("Yes")
#
#
# ye space important hai.
#
#  6) Python me Data Science / AI best hai
#
# Python ka biggest advantage:
# AI, ML, Data Science, Automation me #1 language
#
#  7) Python dynamically typed hai
#
# Python me variable ka type likhna nahi padta.
#
# a = 10
# b = "hi"
#
#
# C/Java me type likhna hota hai:
#
# int a = 10;
#
#  Simple conclusion:
#
#  C/C++ = fast + system programs + games
#  Java = Android + big company projects
#  JavaScript = websites / frontend + backend**

# %% [markdown]
# **4------**

# %% [markdown]
# ** Step 1: Python Install karo (Windows 10)
#
# Google me search karo: python download
#
# python.org open karo
#
# Download Python pe click karo
#
# Setup file open karo
#
#  Important:  Add Python to PATH tick karo
#  Phir Install Now click karo
#
#  Step 2: VS Code Install karo
#
# Google me search karo: VS Code download
#
# Microsoft wala official page open karo
#
# Download for Windows
#
# Install karo (Next-Next)
#
#  Step 3: Python Extension add karo (VS Code me)
#
# VS Code open karo
#
# Left side me Extensions icon (4 boxes) click karo
#
# Search: Python
#
# Install: Python (by Microsoft)
#
#  Step 4: Python file run karo
#
# VS Code me New File open karo
#
# Save karo: test.py
#
# Write karo:
#
# print("Hello Preetam bhai")
#
#
# Run karne ke 2 easy ways:
#
#  Method 1: Run button
#
# Upar right me ▶ Run click karo
#
#  Method 2: Terminal se
#
# VS Code me Terminal open karo:
# Terminal → New Terminal
#
# Type:
#
# python test.py
#
#  Step 5: Check Python version (confirm)
#
# Terminal me:
#
# python --version
#
#  Agar “python is not recognized” error aaya to
#
# Mat tension le bhai, mai fix bata dunga
# Bas mujhe error ka screenshot bhej dena**

# %% [markdown]
# **5------**

# %% [markdown]
# ** Anaconda kya hai? (Easy)
#
# Anaconda ek software hai jo Python ke sath-sath Data Science ke tools ek hi jagah pe de deta hai.
#
# Matlab:
#  Python install
#  Libraries ready
#  Jupyter Notebook ready
#  Environment manage easy
#
#  Anaconda kyu use hota hai?
#
# Normal Python install me ye problem hoti hai:
#
#  bar-bar library install karo
#  version error aata hai (numpy, pandas clash)
#  “module not found” error
#
#  Anaconda se ye sab easy ho jata hai.
#
#  Anaconda me kya-kya milta hai?
#
# Anaconda install karne ke baad aapko milta hai:
#
#  Python Conda (package manager)
# Navigator (GUI app)
#  Jupyter Notebook
#  Spyder IDE
#  Data Science libraries:
#
# NumPy
#
# Pandas
#
# Matplotlib
#
# Scikit-learn
#
#  Conda kya hota hai? (Important)
#
# Conda = Anaconda ka manager tool
#
# Conda se aap:
#  packages install kar sakte ho
#  environments create kar sakte ho
#  python version change kar sakte ho
#
# Example:
#
# conda install numpy
#
#  Environment kya hota hai? (Deep but easy)
#
# Environment = ek separate Python world
#
# Example:
# Aapke PC me 2 projects hai:
#
# Project 1: Old project
#
# Python 3.8
#
# Django 2.2
#
# Project 2: New project
#
# Python 3.12
#
# Django 5
#
# Agar dono ek hi system me mix ho gaye  errors aayenge
#
#  Conda environment se:
# Project 1 ka alag environment
# Project 2 ka alag environment
# Dono safe
#
# Environment ka real-life example
#
# Socho tumhare paas 2 alag kitchens hai
#
#  Kitchen 1 me: Veg food
#  Kitchen 2 me: Non-veg food
#
# Same way environments mix nahi hote
#
#  Anaconda vs Normal Python (Difference)
#  Normal Python:
#
#  light + simple
#  data science libraries alag se install
#  environment manage thoda hard
#
# Anaconda:
#
# all-in-one
#  data science best
# environments easy
#  heavy size (3GB approx)
#
#  Anaconda kab use karna chahiye?
#
#  Agar aap:
#  Data Science
#  AI / ML
#  Jupyter Notebook
#  Pandas / NumPy
# kar rahe ho to Anaconda best
#
#  Anaconda install ke baad basic commands (Most useful)
# 1) Environment create
# conda create -n myenv python=3.10
#
# 2) Environment activate
# conda activate myenv
#
# 3) Package install
# conda install pandas
#
# 4) Environment list
# conda env list
#
# 5) Environment deactivate
# conda deactivate
#
#  Jupyter Notebook kya hai?
#
# Jupyter Notebook ek app hai jisme:
#  Code + Output same page pe
#  Data analysis easy
#  Graph, table easily show
#
# Start karne ke liye:
#
# jupyter notebook
#
#  Simple conclusion
#
# Anaconda = Python + Data science tools + Environments
#  Conda = packages + environment manager
#  Best for AI/ML/Data Science **

# %% [markdown]
#  VS Code Full Installation (Windows 10)
#  Step 1: VS Code Download
#
# Chrome open karo
#
# Google me search karo: VS Code download
#
# Visual Studio Code - Microsoft wali official site open karo
#
# Click:  Download for Windows
#
#  Step 2: VS Code Install
#
# Download ke baad .exe file open karo
#
# Setup me ye options tick karo  (Important)
#
#  Add to PATH (bahut useful)
#  Create a desktop icon
#  Add “Open with Code” action (right click me aata hai)
#
# Phir:
#  Next → Next → Install → Finish
#
# Step 3: VS Code Open karo
#
# Start menu me search karo: VS Code
# Open
#
#  Step 4: Python Extension Install (Must)
#
# Left side me Extensions icon click karo
#
# Search karo: Python
#
# Install karo:  Python (Microsoft)
#
# (Ye extension bina Python run nahi hota properly)
#
#  Step 5: Python install hai ya nahi check karo
#
# VS Code me Terminal open karo:
#  Terminal → New Terminal
#
# Type:
#
# python --version
#
#
# Agar output aaya:
#  Python 3.xx.x
# To perfect
#
#  Step 6: First Python Program Run
#
# VS Code me File → New File
#
# Save karo: hello.py
#
# Code likho:
#
# print("Hello Preetam bhai  N")
#
# Run kaise kare?
#
#  Top right me ▶ Run click karo
# ya terminal me:
#
# python hello.py
#
#  Step 7: Agar “Select Interpreter” aaya to
#
# Ctrl + Shift + P dabao
#
# Type karo: Python: Select Interpreter
#
# Python version select karo
#
#  Step 8: Recommended Extensions (Optional but best)
#
# Extensions me ye bhi install kar sakte ho:
#  Pylance
#  Jupyter (Notebook ke liye)
#  Code Runner (run easy)
#
#  Common Problem Fix
#  python command not found / not recognized
#
# To matlab Python PATH me add nahi hua.
#  Solution: Python reinstall karo aur Add Python to PATH tick karo.

# %% [markdown]
#  Large and Supportive Community ka matlab
#
#  Large
#  Bahut zyada log
#
#  Bahut users / members
#
#
#  Supportive
#
#  Madad karne wale
#
#  Doubt clear karte
#
#  Guide karte
#
#  Community
#
#  Logon ka group
#
#  Jo same cheez seekh rahe ho ya use kar rahe ho

# %% [markdown]
# Cross-Platform Community ka matlab kya hai?
#  Cross-Platform
#
# Alag-alag operating systems par kaam karna
#
# Windows
#
# Linux
#
# macOS
#
# Community
#
#  Logon ka group jo use karta aur help karta hai
#
#  Simple meaning
#
# Cross-platform community = aise log jo alag-alag platforms par Python use karte hain aur ek-dusre ki madad karte hain

# %% [markdown]
#  Rapid Prototyping and Development ka matlab kya hai?
#
#  Rapid = jaldi
#  Prototype = pehla simple model / demo
# Development = poora software banana
#
#  Simple meaning:
#
# Idea ko jaldi se working model banana aur phir usko fast develop karna.
#
#  Python me iska matlab kya hai?
#
# Python me:
#
# Code kam likhna padta hai
#
# Easy syntax hota hai
#
# Ready-made libraries milti hain

# %% [markdown]
# Versatility ka matlab hota hai:
#
# ek hi cheez ka bahut saare kaamon me use ho sakna
#
# Simple words me
#
# Versatility = multi-purpose / flexible
# Python ke example se samjho
#
# Python ko use kiya ja sakta hai:
#
# Web Development
#
# Data Science
#
# Artificial Intelligence
#
# Automation
#
# Game Development
#
# Isi liye Python versatile language hai.
#
# Exam answer (one line)
#
# Versatility ka matlab hai ki ek hi language ko alag-alag kaamon ke liye use kiya ja s
