# %% [markdown]
# **"""variables are container that hold the data values
#
# also know has a identifiers used to hold the value
#
# they hav begin with letters or _underscore
#
# its recommended as a lower case
#
# must be an a alphabet or _underscore
#
# not white space or special character
#
# and not similer to any keywords
#
# and its case sensitive ex= my_name and MyName are not same """**

# %% [markdown]
# **2------**

# %% [markdown]
# **What are Identifiers?
#
# Identifiers are the names used in programming to identify:
#
# variables
#
# functions
#
# classes
#
# object
#  short: An identifier is a name given to a program element**

# %%
message="helloWorld"
print(message)
# Out:
# helloWorld

# %%
""" THIS IS A MULTI LINE COMMENT """

def add(a,b):
    return a+b

""" this function adds two numbers """

add(78 , 93)
# Out:
# 171

# %%
"""  ESCAPING QUOTES """
name="\tRAVI IS A,\n\t\t\t GOOD BOY "
print(name)
# Out:
# 	RAVI IS A,
# 			 GOOD BOY
